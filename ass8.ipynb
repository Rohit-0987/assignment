# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/rohit/OneDrive/Desktop/dataset/titanic.csv")

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Age"]  = df["Age"].fillna(35)
df = df.dropna()
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
import matplotlib as pl
import seaborn as sns

# %%
sns.distplot(df["Age"])
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_16292\2732350774.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df["Age"],bins=40)
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_16292\1786284161.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"],bins=40)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df["Age"],bins=40,kde=False,rug=True)
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_16292\3273591356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"],bins=40,kde=False,rug=True)
# <Axes: xlabel='Age'>

# %%
sns.jointplot(x=df["Age"],y=df["Fare"],kind="scatter")

# %%
sns.jointplot(x=df["Age"],y=df["Fare"],kind="hex")

# %%
sns.pairplot(df)

# %%
sns.barplot(x=df["Sex"],y=df["Fare"])
# Out:
# <Axes: xlabel='Sex', ylabel='Fare'>

# %%
sns.distplot(df['Fare'],hist=True)
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_16292\528468630.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Fare'],hist=True)
# <Axes: xlabel='Fare', ylabel='Density'>
