# %%
from textblob import TextBlob

# %%
b = TextBlob('My namm is Shreyash')

# %%
b.correct()
# Out:
# TextBlob("By name is Shreyash")

# %%
import nltk

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\SHREYASH\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
b1 = TextBlob("Beutiful is better than ugly."
             "Explicit is better than implicit."
             "Simple is better than complex.")
b1.words
# Out:
# WordList(['Beutiful', 'is', 'better', 'than', 'ugly.Explicit', 'is', 'better', 'than', 'implicit.Simple', 'is', 'better', 'than', 'complex'])

# %%
b1.sentences
# Out:
# [Sentence("Beutiful is better than ugly.Explicit is better than implicit.Simple is better than complex.")]

# %%
sent = TextBlob('Use 4 spaces per indentation level')
sent.words
# Out:
# WordList(['Use', '4', 'spaces', 'per', 'indentation', 'level'])

# %%
sent.words[2].singularize()
# Out:
# 'space'

# %%
sent.words[5].pluralize()
# Out:
# 'levels'

# %%
sent.words.count("Per")
# Out:
# 1

# %%
sent.words.count("Per", case_sensitive=True)
# Out:
# 0

# %%
sent.upper()
# Out:
# TextBlob("USE 4 SPACES PER INDENTATION LEVEL")

# %%
sent.find('4')
# Out:
# 4

# %%
from nltk.tokenize import word_tokenize

# %%
document = "Hi! My name is shree, I am studying Data Science and Analytics."

# %%
tokens = word_tokenize(document)
tokens
# Out:
# ['Hi',
#  '!',
#  'My',
#  'name',
#  'is',
#  'shree',
#  ',',
#  'I',
#  'am',
#  'studying',
#  'Data',
#  'Science',
#  'and',
#  'Analytics',
#  '.']

# %%
nltk.download("averaged_perceptron_tagger")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\SHREYASH\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk import pos_tag

# %%
pos_tags = pos_tag(tokens)
pos_tags
# Out:
# [('Hi', 'NN'),
#  ('!', '.'),
#  ('My', 'PRP$'),
#  ('name', 'NN'),
#  ('is', 'VBZ'),
#  ('shree', 'JJ'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('am', 'VBP'),
#  ('studying', 'VBG'),
#  ('Data', 'NNP'),
#  ('Science', 'NNP'),
#  ('and', 'CC'),
#  ('Analytics', 'NNPS'),
#  ('.', '.')]

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\SHREYASH\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words("english"))

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
filtered_tokens = [token for token in tokens if token.lower() not in stop_words]

filtered_tokens
# Out:
# ['Hi',
#  '!',
#  'name',
#  'shree',
#  ',',
#  'studying',
#  'Data',
#  'Science',
#  'Analytics',
#  '.']

# %%
import nltk

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\SHREYASH\AppData\Roaming\nltk_data...
# True

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
stemmed_tokens = [stemmer.stem(token) for token in filtered_tokens]
lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

# %%
stemmed_tokens
# Out:
# ['hi', '!', 'name', 'shree', ',', 'studi', 'data', 'scienc', 'analyt', '.']

# %%
lemmatized_tokens
# Out:
# ['Hi',
#  '!',
#  'name',
#  'shree',
#  ',',
#  'studying',
#  'Data',
#  'Science',
#  'Analytics',
#  '.']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
corpus = [
    "This is the first document.",
    "This document is the second document.",
    "And this is the third one.",
    "Is this the first document?",
]

# %%
vectorizer = TfidfVectorizer()

# %%
tfidf_matrix = vectorizer.fit_transform(corpus)

# %%
tfidf_matrix
# Out:
# <4x9 sparse matrix of type '<class 'numpy.float64'>'
# 	with 21 stored elements in Compressed Sparse Row format>

# %%
feature_names = vectorizer.get_feature_names_out()

feature_names
# Out:
# array(['and', 'document', 'first', 'is', 'one', 'second', 'the', 'third',
#        'this'], dtype=object)

# %%
for doc_index, doc in enumerate(corpus):
    print(f"\nDocument {doc_index + 1}: ")
    for term_index, term in enumerate(feature_names):
        tfidf_value = tfidf_matrix[doc_index, term_index]
        if tfidf_value > 0:
            print(f"{term}: {tfidf_value:.2f}")
# Out:
# Document 1:
# document: 0.47
# first: 0.58
# is: 0.38
# the: 0.38
# this: 0.38
#
# Document 2:
# document: 0.69
# is: 0.28
# second: 0.54
# the: 0.28
# this: 0.28
#
# Document 3:
# and: 0.51
# is: 0.27
# one: 0.51
# the: 0.27
# third: 0.51
# this: 0.27
#
# Document 4:
# document: 0.47
# first: 0.58
# is: 0.38
# the: 0.38
# this: 0.38
